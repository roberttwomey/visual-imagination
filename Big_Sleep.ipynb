# %%
# !pip install big-sleep --upgrade
# Out:
# Requirement already up-to-date: big-sleep in /opt/conda/lib/python3.7/site-packages (0.7.1)
# Requirement already satisfied, skipping upgrade: regex in /opt/conda/lib/python3.7/site-packages (from big-sleep) (2020.11.13)
# Requirement already satisfied, skipping upgrade: pytorch-pretrained-biggan in /opt/conda/lib/python3.7/site-packages (from big-sleep) (0.1.1)
# Requirement already satisfied, skipping upgrade: tqdm in /opt/conda/lib/python3.7/site-packages (from big-sleep) (4.46.0)
# Requirement already satisfied, skipping upgrade: torch>=1.7.1 in /opt/conda/lib/python3.7/site-packages (from big-sleep) (1.7.1+cu101)
# Requirement already satisfied, skipping upgrade: torchvision>=0.8.2 in /opt/conda/lib/python3.7/site-packages (from big-sleep) (0.8.2+cu101)
# Requirement already satisfied, skipping upgrade: einops>=0.3 in /opt/conda/lib/python3.7/site-packages (from big-sleep) (0.3.0)
# Requirement already satisfied, skipping upgrade: ftfy in /opt/conda/lib/python3.7/site-packages (from big-sleep) (5.8)
# Requirement already satisfied, skipping upgrade: fire in /opt/conda/lib/python3.7/site-packages (from big-sleep) (0.4.0)
# Requirement already satisfied, skipping upgrade: numpy in /opt/conda/lib/python3.7/site-packages (from pytorch-pretrained-biggan->big-sleep) (1.18.4)
# Requirement already satisfied, skipping upgrade: requests in /opt/conda/lib/python3.7/site-packages (from pytorch-pretrained-biggan->big-sleep) (2.23.0)
# Requirement already satisfied, skipping upgrade: boto3 in /opt/conda/lib/python3.7/site-packages (from pytorch-pretrained-biggan->big-sleep) (1.16.63)
# Requirement already satisfied, skipping upgrade: typing-extensions in /opt/conda/lib/python3.7/site-packages (from torch>=1.7.1->big-sleep) (3.7.4.2)
# Requirement already satisfied, skipping upgrade: pillow>=4.1.1 in /opt/conda/lib/python3.7/site-packages (from torchvision>=0.8.2->big-sleep) (7.1.2)
# Requirement already satisfied, skipping upgrade: wcwidth in /opt/conda/lib/python3.7/site-packages (from ftfy->big-sleep) (0.1.9)
# Requirement already satisfied, skipping upgrade: termcolor in /opt/conda/lib/python3.7/site-packages (from fire->big-sleep) (1.1.0)
# Requirement already satisfied, skipping upgrade: six in /opt/conda/lib/python3.7/site-packages (from fire->big-sleep) (1.14.0)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests->pytorch-pretrained-biggan->big-sleep) (2020.4.5.1)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests->pytorch-pretrained-biggan->big-sleep) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests->pytorch-pretrained-biggan->big-sleep) (2.9)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests->pytorch-pretrained-biggan->big-sleep) (1.25.9)
# Requirement already satisfied, skipping upgrade: s3transfer<0.4.0,>=0.3.0 in /opt/conda/lib/python3.7/site-packages (from boto3->pytorch-pretrained-biggan->big-sleep) (0.3.4)
# Requirement already satisfied, skipping upgrade: botocore<1.20.0,>=1.19.63 in /opt/conda/lib/python3.7/site-packages (from boto3->pytorch-pretrained-biggan->big-sleep) (1.19.63)
# Requirement already satisfied, skipping upgrade: jmespath<1.0.0,>=0.7.1 in /opt/conda/lib/python3.7/site-packages (from boto3->pytorch-pretrained-biggan->big-sleep) (0.10.0)
# Requirement already satisfied, skipping upgrade: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.7/site-packages (from botocore<1.20.0,>=1.19.63->boto3->pytorch-pretrained-biggan->big-sleep) (2.8.1)

# %%
from tqdm.notebook import trange
from IPython.display import Image, display

from big_sleep import Imagine

TEXT = 'sunrise through a window'#, 'a cat in the refrigerator']
SAVE_EVERY = 100 #@param {type:"number"}
SAVE_PROGRESS = True #@param {type:"boolean"}
LEARNING_RATE = 5e-2 #@param {type:"number"}
ITERATIONS = 1050 #@param {type:"number"}
SEED = 10 #@param {type: "number"}

model = Imagine(
    text = TEXT,
    save_every = SAVE_EVERY,
    lr = LEARNING_RATE,
    iterations = ITERATIONS,
    save_progress = SAVE_PROGRESS,
    seed = SEED
)

for epoch in trange(20, desc = 'epochs'):
    for i in trange(1000, desc = 'iteration'):
        model.train_step(epoch, i)

        if i == 0 or i % model.save_every != 0:
            continue

        filename = TEXT.replace(' ', '_')
        image = Image(f'./%s.png'%filename)
        display(image)
# Out:
# setting seed of 10
# AttributeErrorTraceback (most recent call last)
# <ipython-input-2-5e17820369df> in <module>
#      17     iterations = ITERATIONS,
#      18     save_progress = SAVE_PROGRESS,
# ---> 19     seed = SEED
#      20 )
#      21
#
# /opt/conda/lib/python3.7/site-packages/big_sleep/big_sleep.py in __init__(self, text, text_min, lr, image_size, gradient_accumulate_every, save_every, epochs, iterations, save_progress, bilinear, open_folder, seed, torch_deterministic, max_classes, class_temperature, save_date_time, save_best, experimental_resample, ema_decay)
#     316             "min": []
#     317         }
# --> 318         self.set_text(text, text_min)
#     319
#     320     def encode_one_phrase(self, phrase):
#
# /opt/conda/lib/python3.7/site-packages/big_sleep/big_sleep.py in set_text(self, text, text_min)
#     337         if len(text_min) > 0:
#     338             textpath = textpath + "_wout_" + text_min[:255]
# --> 339         textpath = underscorify(textpath)
#     340         if self.save_date_time:
#     341             textpath = datetime.now().strftime("%y%m%d-%H%M%S-") + textpath
#
# /opt/conda/lib/python3.7/site-packages/big_sleep/big_sleep.py in underscorify(value)
#      65
#      66 def underscorify(value):
# ---> 67   no_punctuation = str(value.translate(str.maketrans('', '', string.punctuation)))
#      68   spaces_to_one_underline = re.sub(r'[-\s]+', '_', no_punctuation).strip('-_') # strip gets rid of leading or trailing underscores
#      69   return spaces_to_one_underline
#
# AttributeError: 'list' object has no attribute 'translate'
